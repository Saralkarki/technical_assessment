# %%
import pandas as pd
import spacy
from spacy import displacy

import matplotlib.pyplot as plt

from collections import Counter
nlp = spacy.load("en_core_web_sm")

import nltk
from nltk import pos_tag
from nltk.stem import PorterStemmer
from nltk import word_tokenize
import time

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
#importing the required datasets
df_1 = pd.read_csv('articles_ns.csv')
df_2 = pd.read_csv('articles_esi.csv')
# Concatenating the two dataframe
df = pd.concat([df_1, df_2], ignore_index=True)

# %%
#convert the date to DateTime type
df.article_date = pd.to_datetime(df.article_date)
# Only articles from 2019
df = df[(df['article_date'].dt.year == 2019)]
#drop empty 
df = df.dropna(how='all')

# %%
# Use the title corpus TF-IDF (Term Frequency – Inverse Document Frequency). 
title_list  = []

for title in df.article_title:
    title_list.append((word_tokenize(title)))

# %%
vectorizer = TfidfVectorizer()

# %%
Y = []
for title in title_list:
    X = vectorizer.fit_transform(title)
    Y.append(X)
# X = vectorizer.fit_transform(title_list)

# %%
Y
# Out:
# [<14x14 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <15x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <12x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <12x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <7x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <13x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <13x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <7x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <10x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <16x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <10x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <13x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <13x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <9x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <14x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <16x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <9x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <10x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <9x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <9x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <7x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <11x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <13x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <15x14 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <10x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <13x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <10x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <9x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <8x6 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6 stored elements in Compressed Sparse Row format>,
#  <8x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <14x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <19x19 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <7x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <16x16 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <9x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <8x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <16x14 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <11x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <14x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <14x14 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <10x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <6x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <9x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <14x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <10x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <13x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <11x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <10x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <14x14 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <15x14 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <15x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <17x15 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <14x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <13x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <6x6 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6 stored elements in Compressed Sparse Row format>,
#  <7x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <10x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <11x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <8x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <8x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <10x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <7x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <14x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <20x18 sparse matrix of type '<class 'numpy.float64'>'
#  	with 20 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <12x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <8x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <12x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <15x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <18x16 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <11x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <15x14 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <10x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <19x16 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <10x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <12x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <13x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <10x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <13x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <9x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <8x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <13x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <8x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <7x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <13x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <13x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <7x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <9x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <14x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <16x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <6x6 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <10x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <14x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <15x15 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <7x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <13x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <15x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <13x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <13x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <13x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <13x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <14x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <9x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <15x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <7x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <16x15 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <14x14 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <6x6 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <15x14 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <18x15 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <8x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <12x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <11x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <10x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <13x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <10x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <5x5 sparse matrix of type '<class 'numpy.float64'>'
#  	with 5 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <10x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <23x18 sparse matrix of type '<class 'numpy.float64'>'
#  	with 21 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <12x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <15x14 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <15x15 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <13x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <7x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <10x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <13x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <14x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <15x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <13x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <17x16 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <8x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <13x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <17x14 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <4x6 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6 stored elements in Compressed Sparse Row format>,
#  <15x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <12x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <10x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <13x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <6x6 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6 stored elements in Compressed Sparse Row format>,
#  <8x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <8x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <14x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <14x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <14x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <13x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <12x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <14x15 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <13x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <14x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <15x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <10x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <10x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <4x4 sparse matrix of type '<class 'numpy.float64'>'
#  	with 4 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <12x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <7x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <14x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <12x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <13x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <12x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <14x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <15x15 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <15x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <15x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <13x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <11x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <10x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <14x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <14x15 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <7x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <16x14 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <15x14 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <10x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <14x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <14x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <10x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <13x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <17x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <13x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <6x6 sparse matrix of type '<class 'numpy.float64'>'
#  	with 6 stored elements in Compressed Sparse Row format>,
#  <8x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <10x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <13x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <10x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <15x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <14x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <11x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <17x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <9x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <9x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <13x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <14x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <13x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <7x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <13x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <15x14 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <14x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <15x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <15x14 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <15x14 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
# ...
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <13x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <12x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <13x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <13x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <10x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <9x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <16x16 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <8x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <13x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <8x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <17x17 sparse matrix of type '<class 'numpy.float64'>'
#  	with 17 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <13x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <17x15 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <7x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <14x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <10x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <14x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <14x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <16x14 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <14x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <15x14 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <12x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <13x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <11x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <11x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <7x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <11x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <10x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <12x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <10x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <12x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <18x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <18x14 sparse matrix of type '<class 'numpy.float64'>'
#  	with 16 stored elements in Compressed Sparse Row format>,
#  <13x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <9x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <13x14 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <13x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <16x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <12x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <13x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <11x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <9x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <7x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <13x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <12x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <12x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <17x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <6x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <13x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <15x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <13x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <13x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <10x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <11x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <8x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <12x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <8x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <13x14 sparse matrix of type '<class 'numpy.float64'>'
#  	with 14 stored elements in Compressed Sparse Row format>,
#  <7x7 sparse matrix of type '<class 'numpy.float64'>'
#  	with 7 stored elements in Compressed Sparse Row format>,
#  <13x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <11x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <12x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <11x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <10x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <12x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <13x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <15x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <12x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <11x8 sparse matrix of type '<class 'numpy.float64'>'
#  	with 8 stored elements in Compressed Sparse Row format>,
#  <12x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <14x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <13x13 sparse matrix of type '<class 'numpy.float64'>'
#  	with 13 stored elements in Compressed Sparse Row format>,
#  <10x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <12x12 sparse matrix of type '<class 'numpy.float64'>'
#  	with 12 stored elements in Compressed Sparse Row format>,
#  <10x11 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <15x15 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <10x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <9x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 9 stored elements in Compressed Sparse Row format>,
#  <10x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <10x9 sparse matrix of type '<class 'numpy.float64'>'
#  	with 10 stored elements in Compressed Sparse Row format>,
#  <11x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  <12x10 sparse matrix of type '<class 'numpy.float64'>'
#  	with 11 stored elements in Compressed Sparse Row format>,
#  ...]

# %%
s = []
for item in Y:
    s.append(item)

# %%
pd.DataFrame(s)
# Out:
#                                                       0
# 0       (0, 5)\t1.0\n  (1, 9)\t1.0\n  (2, 2)\t1.0\n ...
# 1       (0, 5)\t1.0\n  (1, 1)\t1.0\n  (2, 9)\t1.0\n ...
# 2       (0, 10)\t1.0\n  (3, 1)\t1.0\n  (4, 8)\t1.0\n...
# 3       (0, 5)\t1.0\n  (1, 4)\t1.0\n  (2, 0)\t1.0\n ...
# 4       (0, 6)\t1.0\n  (2, 4)\t1.0\n  (3, 1)\t1.0\n ...
# 5       (0, 10)\t1.0\n  (1, 5)\t1.0\n  (2, 6)\t1.0\n...
