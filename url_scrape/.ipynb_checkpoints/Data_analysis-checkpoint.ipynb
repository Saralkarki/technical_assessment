# %%
import pandas as pd
import spacy
from spacy import displacy

import matplotlib.pyplot as plt

from collections import Counter
nlp = spacy.load("en_core_web_sm")

# %%
#importing the required datasets
df_1 = pd.read_csv('articles_ns.csv')
df_2 = pd.read_csv('articles_esi.csv')
# Concatenating the two dataframe
df = pd.concat([df_1, df_2], ignore_index=True)

# %%
plt.plot(df.Country)
# Out:
# Error in callback <function flush_figures at 0x119a4ad90> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     302             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     303         else:
# --> 304             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     305             if not format_dict:
#     306                 # nothing to display (e.g. _ipython_display_ took over)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# </Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/decorator.py:decorator-gen-9> in __call__(self, obj)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2073                     orientation=orientation,
#    2074                     bbox_inches_restore=_bbox_inches_restore,
# -> 2075                     **kwargs)
#    2076             finally:
#    2077                 if bbox_inches and restore_bbox:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     508
#     509         """
# --> 510         FigureCanvasAgg.draw(self)
#     511         renderer = self.get_renderer()
#     512
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1188
#    1189         for tick in ticks_to_draw:
# -> 1190             tick.draw(renderer)
#    1191
#    1192         # scale up the axis label box to also find the neighbors, not
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axis.py in draw(self, renderer)
#     302
#     303         if self.label1On:
# --> 304             self.label1.draw(renderer)
#     305         if self.label2On:
#     306             self.label2.draw(renderer)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/text.py in draw(self, renderer)
#     707
#     708         with _wrap_text(self) as textobj:
# --> 709             bbox, info, descent = textobj._get_layout(renderer)
#     710             trans = textobj.get_transform()
#     711
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     423         # now rotate the positions around the first x,y position
#     424         xys = M.transform(offsetLayout)
# --> 425         xys -= (offsetx, offsety)
#     426
#     427         xs, ys = xys[:, 0], xys[:, 1]
#
# KeyboardInterrupt:

# %%
Counter(df['Company'])
# Out:
# Counter({'Leeward Renewable Energy': 1,
#          'PwrCor': 1,
#          'GEMS': 1,
#          'NEC Energy Solutions': 1,
#          'Energoatom and Holtec': 1,
#          'Assembly': 2,
#          'SCE': 2,
#          'Chevron': 1,
#          '1,000MW': 1,
#          'the Mankato Energy Center': 1,
#          'JERA': 2,
#          'EDA”Source: Company Press': 1,
#          'SSE': 3,
#          'Baseload Capital Sweden': 1,
#          'United Illuminating': 1,
#          'Courtesy of': 1,
#          'AOM': 4,
#          'Eni': 1,
#          'a 2-year Active Output Management 4000': 1,
#          '’s': 28,
#          'FGD': 1,
#          'Maharashtra': 1,
#          'Bank': 4,
#          'NREL': 3,
#          'Tata Power': 1,
#          'Warradarge Wind Farm': 1,
#          'EDF Renewables': 4,
#          'NTPC': 3,
#          '’m': 1,
#          'ScottishPower': 2,
#          'NSW': 2,
#          'Luminant': 1,
#          'EBRD': 10,
#          'the Northern Lights Project': 1,
#          'BayWa': 1,
#          'Circular Finland Program': 1,
#          'West Bengal Power Development Corporation': 1,
#          'the Project.”Source: Company Press': 1,
#          'Engie North America': 1,
#          'Ofgem': 2,
#          'EDF': 5,
#          'KuMax Mono': 1,
#          'the St Brieuc Offshore Windfarm': 1,
#          'MEAG': 1,
#          'Vanadium Redox Flow Battery': 1,
#          '475MW Nysäter': 1,
#          'Brinay': 2,
#          'IBM': 2,
#          'ADB': 6,
#          'Southern Company': 1,
#          'AC': 1,
#          'The Plus EnerG': 1,
#          'EPC': 11,
#          'Senvion': 4,
#          'VAT': 1,
#          'DOE': 4,
#          'Pt/TiO2': 1,
#          'Orsted': 1,
#          'Karmøy': 1,
#          'PID': 1,
#          'AES': 3,
#          'Renewable Energy': 1,
#          'LIPA': 1,
#          'Federal Energy Regulatory Commission': 1,
#          '10%.BMR Energy': 1,
#          'Ministry of the Environment’s Green Bond Guidelines': 1,
#          'Duke Energy': 7,
#          'Endel': 1,
#          'Group': 5,
#          'HVW.Harrison Vickers & Waterman': 1,
#          'EnBW North America': 1,
#          'MW': 14,
#          'Vestas': 6,
#          'Exelon': 1,
#          'the Axium Consortium': 1,
#          'Irsching': 1,
#          '2,806MW': 1,
#          'WPPI Energy': 1,
#          'Abundance.”The': 1,
#          'Transport and Environment': 1,
#          'Fengjigou': 1,
#          'the Vattenfall’s': 1,
#          'WHBO': 1,
#          'New Energy Opportunities': 1,
#          'Rabobank': 1,
#          'the UK.In July': 1,
#          'PKN': 1,
#          'the Eolo Project': 1,
#          'Innovation Saskatchewan': 1,
#          'Breuer': 1,
#          'EPA': 2,
#          'DSM': 2,
#          'NuScale’s Design Certification': 1,
#          'the Chinese State Council': 1,
#          'the Abu Dhabi Fund for Development': 1,
#          'Entergy': 1,
#          'Inquiry Panel': 1,
#          'GE': 14,
#          'Invenergy': 1,
#          'Trinethra Wind & Hydro Power': 1,
#          'Aemetis.“Aemetis': 1,
#          'Beatrice': 2,
#          'the Baynouna Solar Energy Company': 1,
#          'Wales.“Electricity': 1,
#          'EU': 9,
#          'Battery Energy Storage System': 1,
#          'ALTN': 1,
#          'Nemo Link': 1,
#          'Moorlink': 1,
#          'Akuo Energy': 2,
#          'Southern Sky Energy': 1,
#          'FTC': 2,
#          'Lewis Farm': 1,
#          'Fortum': 3,
#          'Commonwealth Bank of Australia': 1,
#          'COO': 1,
#          'the  Energy Center': 1,
#          '487MW': 1,
#          'Signal': 1,
#          'CO₂': 2,
#          'Vermelho': 1,
#          'NTR': 1,
#          'Company’s': 1,
#          'Global Head Corporate Finance/Project Finance': 1,
#          'VTT': 2,
#          'the FPL Dania Beach Clean Energy Center': 1,
#          'Scala Fund Advisory': 1,
#          'Central': 1,
#          'American Water': 3,
#          'Anglesey': 1,
#          'PRS': 1,
#          'the Ministry of Economic Affairs &': 1,
#          'Sanitation Program': 1,
#          'the Qatar Power Transmission System Expansion': 1,
#          'Cleco': 1,
#          'Mr Wood': 1,
#          'Sif’s': 1,
#          'SF6': 1,
#          'Delta Electricity': 1,
#          'RODA': 1,
#          'ACM': 1,
#          'Santa Rita East Wind Farm': 1,
#          'SG': 6,
#          'Lewis': 1,
#          'EGPE': 2,
#          'the United States.”Source: Company Press': 1,
#          'ACCIONA': 2,
#          'Unisun Energy': 1,
#          'GW': 7,
#          'WBSEDCL': 1,
#          'Power Plant': 1,
#          'CBAK Energy': 1,
#          'Programmatic Assistance with Water Data': 1,
#          'Horns Rev': 1,
#          '573MW Race Bank': 1,
#          'EDF Group': 1,
#          'Toshiba ESS': 1,
#          'Company': 2,
#          'Nilar': 1,
#          'LG Chem': 1,
#          'Norske’s': 1,
#          'the Belorechensk Power Plant': 1,
#          'the Scottish Enterprise': 1,
#          'Baltic Eagle': 2,
#          'ACWA Power': 1,
#          'the National Electricity Market': 2,
#          'Londoners': 1,
#          'the Public Utilities Commission of Nevada': 1,
#          'GSE': 1,
#          'GEH': 1,
#          'the Renewable Energy Association': 1,
#          'AECOM Delivery Partner': 1,
#          'EPCC': 1,
#          'Siemens Gamesa': 3,
#          'Juwi': 1,
#          'WaterFix': 1,
#          'Energy': 6,
#          'Parkwind': 1,
#          'Innogy Renewables US': 1,
#          'Kopere Solar Power Project': 1,
#          'Clariant': 1,
#          'Sumitomo': 1,
#          'NRCan': 1,
#          'CONERGIES': 1,
#          'Founder & Executive': 1,
#          'SunShare’s': 1,
#          'Avista': 2,
#          'the Finnish Government': 1,
#          'Mehos': 1,
#          'Ninawa': 1,
#          '’s Iberian': 1,
#          'the Clearwater Project': 1,
#          'Thorsten Blanke': 1,
#          'NBT': 2,
#          'Allianz': 2,
#          'Denmark’s': 1,
#          'Solar Power': 1,
#          'EnVentus': 1,
#          'Special Responsibility for the Energy Management Division': 1,
#          '900MW': 1,
#          'Wylfa Newydd': 1,
#          'World Bank Standards': 1,
#          'the UK.”Source: Company Press': 2,
#          'JinkoSolar': 3,
#          'Hitachi': 2,
#          'HVAC': 4,
#          'Taabo-Agboville': 1,
#          'C&T': 2,
#          'Green Star': 1,
#          'Coldiretti': 1,
#          'GLO': 1,
#          'Gamesa': 2,
#          'V162-5.6 MW': 2,
#          'Solar PV': 1,
#          'Clients': 1,
#          'Goodwill Fund': 1,
#          'Yokogawa': 1,
#          'Amherst': 1,
#          'the Silicon Ranch Project': 1,
#          'National Energy': 1,
#          'Infinity Solar': 1,
#          'PPA': 6,
#          'the Metropolitan Mayors Caucus': 1,
#          'Yellow Door Energy': 1,
#          'WWTP': 1,
#          'Mitsubishi Electric': 1,
#          'NBP': 1,
#          'PlansFujitsu': 1,
#          'MHI Vestas': 2,
#          'York Capital Management': 1,
#          'Columbia Basin Trust': 1,
#          'Hinkley Point C': 1,
#          'RO': 1,
#          'Electric': 1,
#          'Greenlots': 1,
#          'PT Pertamina': 1,
#          'Smart Energy': 1,
#          'Fracta-Esri': 1,
#          'Itron': 1,
#          'Green Source Advantage': 2,
#          'Boralex’s': 2,
#          'The Engineering Services': 1,
#          'Siemens': 5,
#          'ORE Catapult': 2,
#          'Weir': 1,
#          'GE Renewable Energy and Future Wind': 1,
#          'Test & Validation Center': 1,
#          'Clenera': 1,
#          'Funding Group II': 1,
#          'US.To': 1,
#          'TeraPlast': 1,
#          'Doosan Babcock': 1,
#          'The EU Commission': 1,
#          'II': 1,
#          'MMcf/d Aitken Creek Gas Plant': 1,
#          'NextBridge': 1,
#          'Wildflower Solar Energy Center': 1,
#          'IRP': 2,
#          'the US Department of Energy': 1,
#          'DNV-GL.Source: Company': 1,
#          'National Grid': 2,
#          'National Industrial Development and Logistics Program': 1,
#          'Mace': 1,
#          'NIPSCO': 1,
#          'Direct Energy': 3,
#          'the European Union': 4,
#          'HVW': 1,
#          'BlackRock': 1,
#          'Ørsted’s Board of Directors': 1,
#          'ADB’s': 1,
#          'ReneSola’s': 1,
#          'Renewable Energy Water Power Technologies Office': 1,
#          'CenterPoint Energy': 1,
#          'the Food & Water Division': 1,
#          'Church Hill': 1,
#          'DC’s': 1,
#          'Proton Exchange Membrane': 1,
#          'Miller Paving LimitedSource: Company': 1,
#          'Eniig and Fibia': 1,
#          'NRG': 1,
#          'Marathon Capital': 1,
#          'Wilson Sonsini Goodrich & Rosati': 1,
#          'ENUSA': 1,
#          'Eni’s': 1,
#          'Natural Power': 1,
#          'Velilla': 1,
#          'PeroxyChem': 1,
#          'NOK566': 1,
#          'Chickahominy': 1,
#          'Powertis': 1,
#          'Neste MY Renewable Diesel': 2,
#          'Caja Rural de Navarra': 1,
#          'the EERE Exchange': 1,
#          'O&M': 4,
#          'Deutsche Girozentrale': 1,
#          'MIOX': 1,
#          'AMI': 2,
#          'the Tamil Nadu Generation and Distribution Corporation': 1,
#          'DGL': 1,
#          'Dassault Systèmes': 1,
#          'Piauí': 1,
#          'Missouri American Water': 2,
#          'the Public Investment Corporation': 1,
#          'Hull Street Energy': 1,
#          'GWEC': 2,
#          'DP Energy’s': 1,
#          'GaN': 1,
#          'SunPower': 1,
#          'the Marine Corps Air Station Miramar’s': 1,
#          'Watson Decision Platform for Agriculture': 1,
#          'Board of Directors': 1,
#          'Maryland American Water': 1,
#          'PurLucid’s': 1,
#          'NREL.Source: Company Press': 1,
#          'Illinois American Water': 1,
#          'SPD': 1,
#          'Stigafjellet': 1,
#          'the California Independent System Operator': 2,
#          'Vattenfall’s': 2,
#          'Pacific Hydro': 1,
#          'the MHPS G-Series': 1,
#          'EEG': 1,
#          'National Energy and Climate': 1,
#          'Parliament': 1,
#          'FLiDAR': 1,
#          'ARENA': 1,
#          'BECCS': 1,
#          'Bank OCBC NISP': 1,
#          'MABR': 1,
#          'K/S': 1,
#          'the Department of the Interior’s WaterSMART Program': 1,
#          'EDF Energy': 3,
#          'Australian A-CAES': 1,
#          'Tokyo Electric Power': 1,
#          'the PNE Group': 1,
#          'Udipi': 1,
#          'Hamilton Solar Power Plant': 1,
#          'PG&E': 1,
#          'East Anglia': 1,
#          'Pry-Cam': 1,
#          'Melleby': 1,
#          'European Energy': 2,
#          'the Volkswagen Group': 1,
#          'Mainstream’s': 1,
#          'CCA Capital': 1,
#          'MeyGen Phase 1': 1,
#          'Technical': 1,
#          'BPU': 1,
#          'the Los Angeles/Orange Counties Building and Construction Trades Council': 1,
#          'Priority Power': 1,
#          'Deep Isolation’s DNA': 1,
#          'GIP': 1,
#          'Stanford': 1,
#          'E&B': 1,
#          'Delfzijl': 1,
#          'ERG': 3,
#          'REIPPPP': 1,
#          'Vattenfall': 3,
#          'CCGT': 1,
#          'Wirtz': 1,
#          'the Federal Energy Regulatory Commission': 1,
#          'Pentair': 2,
#          'Axium Infrastructure': 1,
#          'Kirkland & Ellis': 1,
#          'Benin': 1,
#          'GDOT': 1,
#          'Shell': 4,
#          'Royal Dutch Shell': 1,
#          'RNG': 2,
#          'WEG': 1,
#          'Fortune Magazine': 1,
#          'FCR': 1,
#          'Ingka Group Ingka Investments': 1,
#          'Dakar': 1,
#          'Kype Muir': 1,
#          'the Wheatridge Renewable Energy Facility': 1,
#          '100bn': 1,
#          'FICO': 1,
#          'R_O_S': 1,
#          'the Russian Government': 1,
#          '’s CO2': 1,
#          'Hyundai Mobis': 1,
#          'Rio Bravo': 1,
#          'NAV': 1,
#          'Equinor': 1,
#          'the US Department of the Interior': 1,
#          'OVO': 1,
#          'Global Infrastructure Partners': 1,
#          'Banco Sabadell': 1,
#          'Power Japan Plus': 1,
#          'Xcel Energy': 2,
#          'the National Renewable Energy Laboratory': 2,
#          'JAC': 1,
#          'EnBW': 3,
#          'McDermott’s': 1,
#          'Department of Energy and Environmental Protection': 2,
#          'Consult': 1,
#          'the Financial Settlement Centre of RE.Source:': 1,
#          'Audi': 1,
#          'GM': 1,
#          'Department’s': 1,
#          'EDPR': 1,
#          'EON': 1,
#          'GreenCom Networks': 1,
#          'NFL': 1,
#          'DEWA': 3,
#          'Valio Development': 1,
#          'NOAH': 1,
#          'New Energy Update': 1,
#          'GTCC': 1,
#          'Liverpool International Business Park': 1,
#          'the East China Power Grid': 1,
#          '349MW': 1,
#          'Universal Electric Corporation': 1,
#          'Bpifrance’s': 1,
#          'Risen Energy': 2,
#          'Daqo New Energy’s': 1,
#          'EMAGIN': 1,
#          'SA Water’s': 1,
#          'New Jersey Resources': 1,
#          'Uttar Pradesh': 1,
#          'Northland Power': 1,
#          'Enegy': 1,
#          'FCV': 1,
#          'EDF Luminus': 1,
#          'Ekip': 1,
#          'Ulstein’s': 1,
#          'ITT': 1,
#          'Cathie Associates': 1,
#          'the Enel Group': 1,
#          'MVDC/HVDC': 1,
#          'LCOE': 2,
#          'the Zenobe Energy': 1,
#          'Lewis & Clark': 1,
#          'Bjerkreim': 1,
#          'Lapetus Solar': 1,
#          'RTS Wind AG': 1,
#          'Izzat Marji Group': 1,
#          'CDE': 1,
#          'DLN': 1,
#          'The Hitachi Capital Group': 1,
#          'the Sharjah Electricity and Water Authority': 1,
#          'EMEC': 1,
#          'Vestas Sales': 1,
#          'First Solar': 1,
#          'PNE AG': 1,
#          'USGS': 1,
#          'Nasdaq Helsinki Ltd': 1,
#          'Energy Sustainability’.Acciona': 1,
#          'LNG': 4,
#          'T&J Industries Development & Contracting Inc. Granite': 1,
#          'Telstra’s NB-IoT': 1,
#          'Air Products': 1,
#          'Ocean DEMO': 1,
#          'AEP': 1,
#          'WIFIA': 1,
#          'MOU': 1,
#          'LO3 Energy’s': 2,
#          'Barbuda': 1,
#          'the Nation Project': 1,
#          'Qilu Transportation Development Group': 1,
#          'STI': 1,
#          'ABB': 5,
#          'OneH2': 1,
#          'Mato Grosso': 1,
#          'Solar Wolf Energy': 1,
#          'The European Commission': 1,
#          'Barrette’s': 1,
#          'Direct Wafer': 1,
#          'the Ford Research and Engineering Campus': 1,
#          'Commission': 4,
#          'Fortune': 2,
#          'Solar Flow': 1,
#          'CO2': 5,
#          'Sandbar’s': 2,
#          'Kerui': 1,
#          'GC': 1,
#          'Sungrow PV & Energy Storage Division': 1,
#          'Central Puerto': 1,
#          'SMA Solar Technology': 1,
#          'Francis': 1,
#          'DNK’s': 1,
#          'L.A.’s': 1,
#          'the DNV GL Energy Transition Programme': 1,
#          'Hanbit Nuclear Power Plant': 1,
#          'Rusnano and Fortum': 1,
#          'EMEC’s': 2,
#          'the State of Paraiba': 1,
#          'CO\xa0': 1,
#          'Jinko Solar': 1,
#          'Enercon': 1,
#          'E.ON': 3,
#          'UPS': 1,
#          'Darlington Point': 1,
#          'Opinion Dynamics': 1,
#          'Oak Ridge National Laboratory': 1,
#          'the Minnesota Pollution Control Agency': 1,
#          'Manson Bolves Donaldson': 2,
#          'IBRD': 1,
#          'USDA': 1,
#          'KACO': 1,
#          'Renewable Energy Project Team': 1,
#          'the World Bank Group’s': 1,
#          'Carbon Engineering’s': 1,
#          'NV Energy': 1,
#          'Samruk-Energy': 1,
#          'CPLS': 1,
#          'Turku': 1,
#          'IPP': 3,
#          'CHP': 2,
#          'World Bank': 2,
#          'Siemens’ Smart Infrastructure Operating Company': 1,
#          'NextEra': 1,
#          'NOMAC': 1,
#          'the Smart Cities': 1,
#          'the Joint Industry Project': 1,
#          'Sunshine Gateway Solar Energy Center': 1,
#          'CLV Nexus': 1,
#          'BluEarth’s': 1,
#          'STEM': 2,
#          'NASA': 1,
#          'Forever Chocolate': 1,
#          'Future Energy Home': 1,
#          'PERC': 3,
#          'Louisiana-Pacific': 1,
#          'NEC': 2,
#          'Google': 1,
#          'the Nordex Group': 2,
#          'Oaktree': 1,
#          'Energy North America': 1,
#          'PREPA': 1,
#          'Black & Veatch Management Consulting': 1,
#          'BEI': 1,
#          'the Ameren Missouri’s': 1,
#          'Cummins': 1,
#          'BBOXX': 2,
#          'UK Energy & Clean': 1,
#          'Groningen': 1,
#          'Enel Green Power': 1,
#          'the Scottish Government': 1,
#          'Eneco': 2,
#          'Jacobs': 1,
#          'Understanding (': 1,
#          'the Wilkinson Solar Energy Center': 1,
#          'IFC': 6,
#          'Cabot Oil & Gas': 1,
#          'Azure Power': 2,
#          'the 485MW Long Ridge Energy Generation Project': 1,
#          'STTR': 1,
#          'Latin America.”Natural Power': 1,
#          'Indiana American Water': 1,
#          'Calgren': 2,
#          'the Morris Ridge': 1,
#          'Geronimo': 1,
#          'RWE': 1,
#          'EDS': 2,
#          'Dogger Bank': 1,
#          'the UK.Source: Company Press': 2,
#          'Academy Securities': 1,
#          'Trump': 2,
#          'The Steering Team': 1,
#          'DTE': 1,
#          'U.S.Tokamaks': 1,
#          'the SEM Committee': 1,
#          'SoftBank': 1,
#          'OWC': 1,
#          'the National Consortium for the Collection, Recycling and Recovery of Plastic Packaging': 3,
#          'UK Power Networks': 1,
#          'the State Government of Victoria': 1,
#          'Avertas Energy': 1,
#          'RES': 3,
#          'the Coega Industrial Development Zone of Port Elizabeth': 1,
#          'Nara Solar': 1,
#          'Columbia': 1,
#          'Halo Energy': 1,
#          'Skeiron': 1,
#          'JRL': 1,
#          'Perry': 1,
#          'Bold Tern': 1,
#          'CIP': 2,
#          'GE Power': 1,
#          'PowerForward': 1,
#          'the New York State Energy Research and Development Authority': 1,
#          'SA Water': 3,
#          'Annet': 1,
#          'Tanum': 1,
#          'Centrica’s': 1,
#          'Project of Common Interest': 1,
#          'SMA Sunbelt Energy GmbH': 1,
#          'TVA': 1,
#          'CyrusOne’s': 1,
#          'CellCube': 2,
#          'CATL': 1,
#          'Trianel': 1,
#          'Van Oord': 1,
#          'Onslow': 1,
#          'CTG.DEME Offshore': 1,
#          'Rajasthan': 1,
#          'Ocean Sun': 1,
#          'LP&L': 1,
#          'Commonwealth': 1,
#          'Cypress': 1,
#          'IronNet': 1,
#          'the Nuclear Suppliers Group': 1,
#          'Wärtsilä Lifecycle': 1,
#          'the Millbrook Power Station': 1,
#          'Constant': 1,
#          'LLC': 3,
#          'the ENGIE Group': 1,
#          'SCR': 1,
#          'Alinta Energy': 1,
#          'ION Engineering': 1,
#          'Holland Coast South': 1,
#          'Crockett Counties': 1,
#          'the European Commission': 1,
#          'TSS': 1,
#          'Nelja Energia': 1,
#          'Gold King': 1,
#          'HVC & Sunwatt': 1,
#          'IRENA': 3,
#          'Oxford PV': 1,
#          'the North Carolina Utilities Commission': 1,
#          'Suntech': 1,
#          'State': 1,
#          'CEC’s': 1,
#          'Calpine': 1,
#          'DNV GL': 2,
#          'Green Economy Transition': 1,
#          'Bangladesh’s': 1,
#          'Corporation': 1,
#          'Dairyland’s': 1,
#          'the New Jersey Solar Renewable Energy Credit Program': 1,
#          'NEXTracker': 1,
#          'the Arkansas Public Service Commission': 1,
#          'Race Bank': 1,
#          'Thunder Basin Coal Company': 1,
#          'Organization of the Petroleum Exporting Countries': 1,
#          'Open Energy': 1,
#          'SAWACO': 1,
#          'Cyclades': 1,
#          'SMR': 1,
#          'TSK': 1,
#          'AFD': 1,
#          'Ofgem’s': 1,
#          'Avista’s': 1,
#          'WPA': 1,
#          'CAGR': 1,
#          'the National Grid': 1,
#          'Sunergise New Zealand': 1,
#          'Black & Veatch’s': 1,
#          'Colton': 1,
#          'MAP Renewable Energy': 1,
#          'the Production Tax Credit and Investment Tax Credits': 1,
#          'Rostock': 2,
#          'the Swedish Energy Agency': 1,
#          'GranBio': 1,
#          'Schneider Electric': 1,
#          'Amprion': 1,
#          'Allianz Capital Partners': 1,
#          'Grain Belt Project': 1,
#          'Qingdao Pilot National Laboratory for Marine Science and Technology': 1,
#          'Asset': 1,
#          'THERMI SUN S.A.': 1,
#          'ClearView Power': 1,
#          'Ockerman Automation': 1,
#          'Triton Knoll': 1,
#          'IDB': 1,
#          'GW.The EDF Group': 1,
#          'Merivale Transmission Station': 1,
#          'Nurek': 1,
#          'Regenerative Motion Recharge System': 1,
#          'Electrification Financing Initiative (ElectriFI': 1,
#          'GIG': 2,
#          'MRPR': 1,
#          'Anergy’s': 1,
#          'the Zhuhai Gaolan Port Economic Zone': 1,
#          'the Oil & Gas Authority': 1,
#          'SSEN': 2,
#          'NW Natural Water': 1,
#          'AED50bn': 1,
#          'the Vogtle 3 & 4': 1,
#          'GE Renewable Energy': 2,
#          'IV': 1,
#          'M&A': 1,
#          'Tidewater’s': 1,
#          'SGT': 1,
#          'InfluenceMap': 1,
#          'Great Britain’s': 1,
#          'Innergex': 1,
#          'Predictive': 1,
#          'Peikko Group Corporation': 1,
#          'Business Development': 1,
#          'the Association of Power Utilities of Africa': 1,
#          'ACC': 1,
#          'Emera Maine': 1,
#          'Energy Florida': 1,
#          'TransAlta': 1,
#          'IEA': 5,
#          'Alpha': 1,
#          'Uch': 1,
#          'Wireless Power': 1,
#          'the Northern Ireland Utility Regulator': 1,
#          'UGTC’s': 1,
#          'The Wonderful Company': 1,
#          'Low Carbon Power Fund': 1,
#          'Andromeda PV': 1,
#          'ASRE': 1,
#          'the Water and Waste Disposal Loan': 1,
#          'Fluence’s': 2,
#          'Nexans Power Accessories Germany': 1,
#          'Ranked': 1,
#          'MHPS': 4,
#          'US Water Services': 1,
#          'the 1,292MW Hub Power Plant': 1,
#          'GlobalData': 1,
#          'Water Rodney Clemente': 1,
#          'UN': 3,
#          'U.S. Wind Power': 1,
#          'Wello': 1,
#          'TEP': 1,
#          'Consumers Energy': 1,
#          '’s Changhua': 1,
#          'Star of the South': 1,
#          'FPL': 2,
#          'the Austrian Research Promotion Agency': 1,
#          'First Nations': 1,
#          'UXO': 1,
#          'MSA’s Americas': 1,
#          'Fund': 1,
#          'WEC': 1,
#          'MRP': 1,
#          'the Chinese Government': 1,
#          'Peoples': 1,
#          'Plant Engineering': 1,
#          'the Italian Biogas Consortium and Eni': 1,
#          'Senate': 1,
#          'National Marine Renewable Energy Centers': 1,
#          'this Facility.”Source: Company Press': 1,
#          'Hornsea One': 2,
#          'CPS': 1,
#          'Smart Meter Program Strategy and Implementation': 1,
#          'GoSolar Shares': 1,
#          'DNVGL-SE-0422.The company': 1,
#          'Constant Energy': 1,
#          'JD Aviation': 1,
#          'CCUS': 3,
#          'UAE’s': 1,
#          'EGA': 1,
#          'Nordex Group': 3,
#          'the National Energy and Climate Plan': 1,
#          'ACWA Power Zarqa': 1,
#          'Shell’s': 1,
#          'The World Commission on Dams': 1,
#          'Natixis': 1,
#          'the Emirate of Sharjah': 1,
#          'GE Lighting': 1,
#          'National': 1,
#          'SPIC': 1,
#          'ROBUR.Source: Company Press': 1,
#          'Foresight': 1,
#          'ARC': 1,
#          'APS': 2,
#          'the SeaTwirl Pilot': 1,
#          'Moeller': 1,
#          'Grid Solutions': 1,
#          'CleanCapital': 1,
#          'Fenix': 1,
#          'Innolith': 1,
#          'Orkney': 1,
#          'DRC’s': 1,
#          'Mauritius': 2,
#          'Taiwan Power Company': 1,
#          'BEC': 1,
#          'PJM': 1,
#          'Bank of America': 1,
#          'Luxel': 1,
#          'SolarReserve': 1,
#          'the German Export Credit Agency': 1,
#          'EIA': 1,
#          'Snowy Hydro Limited': 1,
#          'the U.S. Department of Agriculture': 1,
#          'FE': 1,
#          'the Department of Natural Resources, Mines and Energy (DNRME': 1,
#          'Water-Right': 1,
#          'Clearway': 1,
#          'the State Revolving Fund': 1,
#          'Government': 4,
#          'The Government Pension Fund': 1,
#          'MMTP': 1,
#          'CCSA': 1,
#          'Turkmen': 1,
#          'the North Middletown Utility System': 2,
#          'ASEAN Catalytic Green Finance': 1,
#          'The Official Receiver': 1,
#          'the\xa0Senate Standing Committee\xa0on Energy, Utilities and Communications': 1,
#          'NJEDA': 1,
#          'GlidePath': 1,
#          'WTG': 1,
#          'FENOC': 1,
#          'Volvo Bus': 1,
#          'GPGC.Source: Company Press': 1,
#          'Central Electric': 1,
#          'BizSavers Program': 1,
#          'Small Power & Lighting, Fire & Hydrogen Detection and Physical & Electronic Security': 1,
#          'Seacat Services': 1,
#          'ENGIE': 2,
#          'Braskem’s': 1,
#          'Siemens DD': 1,
#          'Wood Mackenzie': 1,
#          'BC Hydro': 1,
#          'the Napa County Board of Supervisors': 1,
#          'AWEA': 1,
#          'B. Grimm Power': 1,
#          'the Connecticut Green Bank': 1,
#          'IESO': 1,
#          'de-Nox': 1,
#          'Dominion Energy': 1,
#          'Ashley': 1,
#          'Solpod': 1,
#          'Pecos': 1,
#          'Wanzek Construction': 1,
#          'Utopus Insights': 1,
#          'Power Purchase Agreements': 1,
#          'the University of Chester Energy Centre': 1,
#          'Lukaszow': 1,
#          'Keppel O&M’s': 1,
#          'Natural Resources Canada': 1,
#          'Carlyle’s': 1,
#          'Soletair Power': 1,
#          'O&M Service': 1,
#          'USTDA': 1,
#          'Coal-Based Power Plants of the Future': 1,
#          'Fisher and Sons': 1,
#          'Electrix': 1,
#          'NIB': 1,
#          'Jebel Ali E Power Station': 1,
#          'Westech Industrial Ltd': 1,
#          'the Regi Lagni – Naples': 1,
#          'UiTM Holdings': 1,
#          'CfD': 1,
#          'Starbucks': 1,
#          'ALLETE': 1,
#          'Renewable': 1,
#          'Nordics': 1,
#          'AGL': 1,
#          'sPower': 1,
#          'Microsoft': 2,
#          'the Siemens Gamesa Renewable Energy Offshore Business Unit': 1,
#          'PNE': 1,
#          'Black & Veatch’s Mumbai': 1,
#          'Crawford International': 1,
#          'Tranche VI': 1,
#          'Altus Power': 1,
#          'the Orot Rabin Power Station': 1,
#          'Sinobioway': 1,
#          'Solarcentury': 2,
#          'BUA': 1,
#          'United Power’s': 1,
#          'the Center for Hybrid Organic Inorganic Semiconductors for Energy': 1,
#          'EMF': 1,
#          'the Securities and Exchange Commission': 1,
#          'Talasol': 1,
#          'Gujarat': 1,
#          'Energy Saving of Ukraine': 1,
#          'the California Public Utilities Commission': 1,
#          'CORC': 1,
#          'JMP': 1,
#          'The National Energy Plans': 1,
#          'AEP’s': 1,
#          'manner.”Austin Energy': 1,
#          '300MW': 1,
#          'Fincantieri': 1,
#          'PRES': 1,
#          'Tecsur': 1,
#          'Chemours Fluoroproducts': 1,
#          'WSS': 1,
#          'EnergyLink': 1,
#          'Rügen': 1,
#          'Mesteño Wind Project': 1,
#          'Equis Energy': 1,
#          'TSMC': 1,
#          'ACCIONA Industrial and Imasa': 1,
#          'Pacific Power': 1,
#          'the Power Grid Corporation of India': 1,
#          'Mr Vyakaranam.“Morocco': 1,
#          'Entergy’s': 1,
#          'Offshore': 1,
#          'Power Grids': 1,
#          'the Fund’s': 1,
#          'the Millington Middle School STEM Robotics': 1,
#          'Inventory of U.S. Greenhouse Gas Emissions and Sinks': 1,
#          'Nuvia': 1,
#          'Scope 2': 1,
#          'Phoebe': 1,
#          'DREWAG': 1,
#          'Black & Veatch': 2,
#          'SynTech': 1,
#          'Watercare Executive Programme': 1,
#          'EDC': 2,
#          'TÜV SÜD’s': 1,
#          'AARP': 1,
#          'O’Neil': 1,
#          'University': 2,
#          'Product Development at ECG.Source: Company Press': 1,
#          'CleanMax Solar': 1,
#          'Enel': 2,
#          'the West Damietta Power Plant': 1,
#          'SDTC': 1,
#          'Clearway Energy Group': 1,
#          'Netzsch': 1,
#          'Gävle Elbyggnads i Gävle AB': 1,
#          'Celluapp': 1,
#          'Ocean Energy Europe': 1,
#          'Godawari Green Energy': 1,
#          'Sustainability Services': 1,
#          'Bergama Plant': 1,
#          'Longannet': 1,
#          'The Cutia Wind Complex': 1,
#          'GCF).The': 1,
#          'Önusberget': 1,
#          'ICOL': 1,
#          'New York’s Energy': 1,
#          'Sub-Saharan Africa': 1,
#          'Hawaiian Electric': 1,
#          'FairWind': 1,
#          'Lincoln Gap Wind Farm': 1,
#          'SKH': 1,
#          'Canadian Solar’s': 1,
#          'Norther': 1,
#          'Dangjin': 1,
#          'Department of the Interior': 1,
#          'E.ON’s': 2,
#          'EIB': 2,
#          'National Renewable Energy Action Plan': 1,
#          'Méligny-le-Grand': 1,
#          'the Alberta Investment Management Corporation': 1,
#          'GCR': 1,
#          'M-Station': 1,
#          'NuScale’s': 2,
#          'Siemens Gamesa’s': 2,
#          'Nam Dinh 1 IPP.On': 1,
#          'Hannibal': 1,
#          'SigurdKvistad of Hafslund': 1,
#          'Ørsted’s': 1,
#          'kV': 1,
#          'MPC Renewable Energies': 1,
#          'Electric Completed Projects': 1,
#          'the U.S. Forest Service’s': 1,
#          'Coronal Energy': 1,
#          'Asset Operations': 1,
#          'Energy Service Experts': 1,
#          'Project': 1,
#          'Lesedi CBM': 1,
#          'European Clean Energy Infrastructure': 1,
#          'PNM Resources': 1,
#          'French Ministry of Economy and Finance': 1,
#          'NMS': 1,
#          'Novovoronezh': 1,
#          'Wood': 2,
#          'the GAS-TESS': 1,
#          'Eco Innovation District': 1,
#          'Bitfarms': 1,
#          'Crews': 1,
#          'ERCOT': 1,
#          'General Electric Global Research': 1,
#          'ENEA': 1,
#          'PLC': 1,
#          'the University of New South Wales': 1,
#          'Urbasolar': 1,
#          'ABO Wind Espaňa S.A.U.': 1,
#          'VALOREM': 1,
#          'the Mohammed bin Rashid': 1,
#          'ETAP': 1,
#          'the South Electricity Distribution Company': 1,
#          'Clean Energy': 1,
#          'Power Roll': 1,
#          'PURA.Source: Company Press': 1,
#          'Asia Pacific Infrastructure': 1,
#          'Energy Savings Agreements': 1,
#          'Southwestern Energy': 1,
#          'Preem’s': 1,
#          'Akamai': 1,
#          '2022.The Morris Ridge Solar Project': 1,
#          'GEF': 1,
#          '25-øren).The Danish Energy Agency': 1,
#          'Green Data Center': 1,
#          'AC Energy': 1,
#          'NorthWestern': 1,
#          'SunShare': 1,
#          'Star Power Services': 1,
#          'Huesca': 1,
#          'Innovation Hubs': 1,
#          'LinkedIn Group': 1,
#          'DolWin': 1,
#          'Scatec Solar’s': 1,
#          'SCA': 1,
#          'Vogtle': 1,
#          'Exelon Generation': 1,
#          'BSMI': 1,
#          'LO3 Energy': 1,
#          ...})
